# %% [markdown]
# # Matrix Multiplication

# %%
from matplotlib import pyplot as plt
import matplotlib
import numpy as np
# %matplotlib inline

import seaborn as sns; sns.set()
plt.rcParams["figure.figsize"] = (16,8)

# %% [markdown]
# ### Machine specification

# %% [markdown]
# - Processor: CPUIntel Core i7 (7th Gen) 7700HQ / 2.8 GHz
# - Max Turbo Speed: 3.8 GHz
# - Number of Cores: 4
# - Number of threads: 8
# - L3 Cache: 6 MB
# - L2 Cache: 1 MB
# - L1 Cache: 256 KB

# %% [markdown]
# ### Benchmarks

# %% [markdown]
# The following benchmarks were recorded for each of the six possible permutations of IJK loop order.

# %% [markdown]
#     for (int i = 0; i < N; i++) {
#         for (int j = 0; j < N; j++) {
#             for (int k = 0; k < N; k++) {
#                 C[i][j] += A[i][k] * B[k][j];
#             }
#         }
#     }

# %% [markdown]
# In addition, benchmarks for one possible loop unrolling were collected:

# %% [markdown]
# 	for (int i = 0; i < N; i++) {
# 		for (int j = 0; j < N; j++) {
# 			for (int k = 0; k < N; k += 4) {
# 				double * aik = &A[i][k];
# 				C[i][j] += aik[0] * B[k][j]
# 						+ aik[1] * B[k + 1][j]
# 						+ aik[2] * B[k + 2][j]
# 						+ aik[3] * B[k + 3][j];
# 			}
# 		}
# 	}

# %%
data = {'I J K': [11013, 11066, 10542, 11069, 10937, 11089]}
data['I K J'] = [3860, 3775, 3779, 3806, 3799, 3760]

data['K J I'] = [10908, 11360, 11620, 12615, 11240, 11704]
data['K I J'] = [4014, 4023, 3964, 3889, 3907, 4073]

data['J I K'] = [7394, 7354, 7363, 7415, 7213, 7013]
data['J K I'] = [15689, 15514, 15519, 15601, 15478, 15406]

data['Loop unrolled'] =  [7514, 7663, 7400, 7530, 7625, 7765]

# %%
def plot_performance_stats():
    run = np.arange(6)
    fig, ax = plt.subplots()
    
    for k, v in data.items():
        plt.plot(run, v, label=k)
   
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.08), ncol=7) 
    
    plt.xlabel('Run number')
    plt.ylabel('Clocks')
    plt.title('Matrix multiplication clock times')

plot_performance_stats()

# %% [markdown]
# The fastest loop order (on my machine) was **IKJ**
