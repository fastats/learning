# %%
from datetime import date, timedelta
from contextlib import contextmanager
import time
import os

import numpy as np
import pandas as pd


IDENT_BASE = "ABC"


def gen_identifiers(n=3000):
    return [IDENT_BASE + str(x).zfill(6)
            for x in range(n)]


def gen_dates(n=3000):
    today = date.today()
    start = today - timedelta(days=n)
    return pd.date_range(start, today)


def gen_data():
    ids = gen_identifiers()
    dates = gen_dates()
    data = np.random.random(len(ids))

    results = []
    for date in dates:
        df = pd.DataFrame({
            'identifier': ids,
            'value': data
        })
        df['date'] = date
        results.append(df)

    return pd.concat(results)

df = gen_data()
print(f'DataFrame: {df.shape}')
# Out:
# DataFrame: (9003000, 3)

# %%
def test_and_benchmark(func_to_benchmark, file_name, func_to_read, is_h5=False, *args, **kwargs):
    """
    Test and benchmark a given algorithm to compress a dataframe.
    """
    start = time.perf_counter()
    func_to_benchmark(file_name, *args, **kwargs)
    save_time = time.perf_counter() - start
    
    start = time.perf_counter()

    if is_h5:
        func_to_read(file_name, key='df')
    else:
        func_to_read(file_name)

    load_time = time.perf_counter() - start
    
    size_in_bytes = os.path.getsize(file_name)
    
    res = {
        'file_name': file_name,
        'save_time': save_time,
        'load_time': load_time,
        'file_size': size_in_bytes
    }
    
    print(res)

    return res

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9003000 entries, 0 to 2999
# Data columns (total 3 columns):
# identifier    object
# value         float64
# date          datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 274.7+ MB

# %%
h_compression_engines = [
    'zlib', 'lzo', 'bzip2', 'blosc',
    'blosc:blosclz', 'blosc:lz4', 'blosc:lz4hc',
    'blosc:snappy', 'blosc:zlib', 'blosc:zstd'
]

records = []
for comp_engine in h_compression_engines:
    for c_level in range(1, 10):
        result = test_and_benchmark(
            df.to_hdf,
            f'lvl{c_level}_{comp_engine}_initial.h5',
            pd.read_hdf,
            complib=comp_engine,
            complevel=c_level,
            key='df',
            is_h5=True
        )
        records.append(result)

for parq_engine in ['snappy', 'gzip', 'brotli']:
    res = test_and_benchmark(
        df.to_parquet,
        f'{parq_engine}_initial.parquet',
        pd.read_parquet,
        compression=parq_engine,
    )
    records.append(res)
# Out:
# {'file_name': 'lvl1_zlib_initial.h5', 'save_time': 1.9251981999999999, 'load_time': 1.1804757999999997, 'file_size': 128683644}
# {'file_name': 'lvl2_zlib_initial.h5', 'save_time': 1.5262379, 'load_time': 1.2209019999999997, 'file_size': 128683603}
# {'file_name': 'lvl3_zlib_initial.h5', 'save_time': 1.5083728, 'load_time': 1.2270727, 'file_size': 128683459}
# {'file_name': 'lvl4_zlib_initial.h5', 'save_time': 1.9430028999999998, 'load_time': 1.300381999999999, 'file_size': 128389366}
# {'file_name': 'lvl5_zlib_initial.h5', 'save_time': 1.9347189, 'load_time': 1.2645329999999984, 'file_size': 128403136}
# {'file_name': 'lvl6_zlib_initial.h5', 'save_time': 1.9884337999999993, 'load_time': 1.2461622999999982, 'file_size': 128399712}
# {'file_name': 'lvl7_zlib_initial.h5', 'save_time': 1.9756, 'load_time': 1.2566148999999989, 'file_size': 128372460}
# {'file_name': 'lvl8_zlib_initial.h5', 'save_time': 2.011139100000001, 'load_time': 1.2440635000000029, 'file_size': 128320512}
# {'file_name': 'lvl9_zlib_initial.h5', 'save_time': 1.925217400000001, 'load_time': 1.2358505000000015, 'file_size': 128319923}
# {'file_name': 'lvl1_lzo_initial.h5', 'save_time': 1.0114376000000007, 'load_time': 1.117738799999998, 'file_size': 140190352}
# {'file_name': 'lvl2_lzo_initial.h5', 'save_time': 0.9344846999999987, 'load_time': 1.1206600000000044, 'file_size': 140190352}
# {'file_name': 'lvl3_lzo_initial.h5', 'save_time': 0.9682348999999988, 'load_time': 1.1230091000000044, 'file_size': 140190352}
# {'file_name': 'lvl4_lzo_initial.h5', 'save_time': 0.9321809999999999, 'load_time': 1.1139527999999999, 'file_size': 140190352}
# {'file_name': 'lvl5_lzo_initial.h5', 'save_time': 0.9458637000000039, 'load_time': 1.1190546000000055, 'file_size': 140190352}
# {'file_name': 'lvl6_lzo_initial.h5', 'save_time': 0.9526210000000006, 'load_time': 1.1236516000000023, 'file_size': 140190352}
# {'file_name': 'lvl7_lzo_initial.h5', 'save_time': 1.0001456999999974, 'load_time': 1.1165762999999984, 'file_size': 140190352}
# {'file_name': 'lvl8_lzo_initial.h5', 'save_time': 0.935944499999998, 'load_time': 1.1478333999999961, 'file_size': 140190352}
# {'file_name': 'lvl9_lzo_initial.h5', 'save_time': 0.9583352000000005, 'load_time': 1.2222647000000038, 'file_size': 140190352}
# {'file_name': 'lvl1_bzip2_initial.h5', 'save_time': 8.386686399999995, 'load_time': 2.7770598000000035, 'file_size': 136284145}
# {'file_name': 'lvl2_bzip2_initial.h5', 'save_time': 7.7997608000000085, 'load_time': 2.772354100000001, 'file_size': 135475488}
# {'file_name': 'lvl3_bzip2_initial.h5', 'save_time': 8.17804120000001, 'load_time': 3.0105501000000032, 'file_size': 135475488}
# {'file_name': 'lvl4_bzip2_initial.h5', 'save_time': 8.421554100000009, 'load_time': 2.9841505000000126, 'file_size': 135475488}
# {'file_name': 'lvl5_bzip2_initial.h5', 'save_time': 8.181652999999997, 'load_time': 3.0944941999999998, 'file_size': 135475488}
# {'file_name': 'lvl6_bzip2_initial.h5', 'save_time': 8.3168644, 'load_time': 3.0088803000000013, 'file_size': 135475488}
# {'file_name': 'lvl7_bzip2_initial.h5', 'save_time': 8.292680500000003, 'load_time': 3.0683526000000114, 'file_size': 135475488}
# {'file_name': 'lvl8_bzip2_initial.h5', 'save_time': 8.221417200000019, 'load_time': 3.187060400000007, 'file_size': 135475488}
# {'file_name': 'lvl9_bzip2_initial.h5', 'save_time': 8.510162500000007, 'load_time': 2.997298900000004, 'file_size': 135475488}
# {'file_name': 'lvl1_blosc_initial.h5', 'save_time': 0.9864049999999907, 'load_time': 1.0470870000000048, 'file_size': 179808664}
# {'file_name': 'lvl2_blosc_initial.h5', 'save_time': 0.9685970000000168, 'load_time': 1.0555420000000026, 'file_size': 128861576}
# {'file_name': 'lvl3_blosc_initial.h5', 'save_time': 1.0461676999999838, 'load_time': 1.0694024000000013, 'file_size': 128861576}
# {'file_name': 'lvl4_blosc_initial.h5', 'save_time': 0.9627044000000069, 'load_time': 1.028193000000016, 'file_size': 128861576}
# {'file_name': 'lvl5_blosc_initial.h5', 'save_time': 0.9960070999999857, 'load_time': 1.0402071000000035, 'file_size': 128861576}
# {'file_name': 'lvl6_blosc_initial.h5', 'save_time': 0.991097400000001, 'load_time': 1.0294717999999818, 'file_size': 128861576}
# {'file_name': 'lvl7_blosc_initial.h5', 'save_time': 1.0522837999999979, 'load_time': 1.0464805000000013, 'file_size': 128861576}
# {'file_name': 'lvl8_blosc_initial.h5', 'save_time': 1.3931537999999932, 'load_time': 1.0874086999999975, 'file_size': 128861576}
# {'file_name': 'lvl9_blosc_initial.h5', 'save_time': 0.9827109999999948, 'load_time': 1.0512463999999966, 'file_size': 128861576}
# {'file_name': 'lvl1_blosc:blosclz_initial.h5', 'save_time': 1.055144299999995, 'load_time': 1.056971500000003, 'file_size': 179808704}
# {'file_name': 'lvl2_blosc:blosclz_initial.h5', 'save_time': 0.9865369999999984, 'load_time': 1.0665578999999923, 'file_size': 128861616}
# {'file_name': 'lvl3_blosc:blosclz_initial.h5', 'save_time': 1.0019609999999943, 'load_time': 1.0203487999999936, 'file_size': 128861616}
# {'file_name': 'lvl4_blosc:blosclz_initial.h5', 'save_time': 0.9970085999999867, 'load_time': 1.0278168000000107, 'file_size': 128861616}
# {'file_name': 'lvl5_blosc:blosclz_initial.h5', 'save_time': 1.0583502000000067, 'load_time': 1.0270233999999903, 'file_size': 128861616}
# {'file_name': 'lvl6_blosc:blosclz_initial.h5', 'save_time': 1.0188156000000106, 'load_time': 1.0234638999999959, 'file_size': 128861616}
# {'file_name': 'lvl7_blosc:blosclz_initial.h5', 'save_time': 1.0201721999999904, 'load_time': 1.0734786000000156, 'file_size': 128861616}
# {'file_name': 'lvl8_blosc:blosclz_initial.h5', 'save_time': 0.9827171000000021, 'load_time': 1.1405321000000015, 'file_size': 128861616}
# {'file_name': 'lvl9_blosc:blosclz_initial.h5', 'save_time': 1.1974891000000127, 'load_time': 1.1336081999999976, 'file_size': 128861616}
# {'file_name': 'lvl1_blosc:lz4_initial.h5', 'save_time': 0.9768004000000019, 'load_time': 1.1011485999999877, 'file_size': 128578198}
# {'file_name': 'lvl2_blosc:lz4_initial.h5', 'save_time': 0.9472799000000123, 'load_time': 1.1484465999999998, 'file_size': 128538260}
# {'file_name': 'lvl3_blosc:lz4_initial.h5', 'save_time': 0.9491276999999911, 'load_time': 1.0337152000000174, 'file_size': 128553551}
# {'file_name': 'lvl4_blosc:lz4_initial.h5', 'save_time': 0.9499879000000249, 'load_time': 1.0478061000000025, 'file_size': 128552074}
# {'file_name': 'lvl5_blosc:lz4_initial.h5', 'save_time': 0.9243529000000024, 'load_time': 1.0479162999999971, 'file_size': 128597063}
# {'file_name': 'lvl6_blosc:lz4_initial.h5', 'save_time': 0.959974399999993, 'load_time': 1.0447486999999853, 'file_size': 128538238}
# {'file_name': 'lvl7_blosc:lz4_initial.h5', 'save_time': 0.9536389000000156, 'load_time': 1.077623200000005, 'file_size': 128539246}
# {'file_name': 'lvl8_blosc:lz4_initial.h5', 'save_time': 0.9732223000000033, 'load_time': 1.060463800000008, 'file_size': 128538314}
# {'file_name': 'lvl9_blosc:lz4_initial.h5', 'save_time': 1.4884860999999887, 'load_time': 1.0493804000000182, 'file_size': 128538294}
# {'file_name': 'lvl1_blosc:lz4hc_initial.h5', 'save_time': 1.0311053000000072, 'load_time': 1.0700016000000119, 'file_size': 128507974}
# {'file_name': 'lvl2_blosc:lz4hc_initial.h5', 'save_time': 1.0606634999999756, 'load_time': 1.0918958999999973, 'file_size': 128507974}
# {'file_name': 'lvl3_blosc:lz4hc_initial.h5', 'save_time': 1.0375650999999948, 'load_time': 1.0805140999999878, 'file_size': 128507675}
# {'file_name': 'lvl4_blosc:lz4hc_initial.h5', 'save_time': 1.0645760000000166, 'load_time': 1.0923955000000092, 'file_size': 128507383}
# {'file_name': 'lvl5_blosc:lz4hc_initial.h5', 'save_time': 1.0830825999999831, 'load_time': 1.0686249000000032, 'file_size': 128507382}
# {'file_name': 'lvl6_blosc:lz4hc_initial.h5', 'save_time': 1.0736451999999872, 'load_time': 1.0546423000000118, 'file_size': 128507349}
# {'file_name': 'lvl7_blosc:lz4hc_initial.h5', 'save_time': 1.1204884999999933, 'load_time': 1.0555793999999992, 'file_size': 128507284}
# {'file_name': 'lvl8_blosc:lz4hc_initial.h5', 'save_time': 1.5784505999999965, 'load_time': 1.1018052999999952, 'file_size': 128507134}
# {'file_name': 'lvl9_blosc:lz4hc_initial.h5', 'save_time': 1.6927253000000064, 'load_time': 1.048642000000001, 'file_size': 128507134}
# {'file_name': 'lvl1_blosc:snappy_initial.h5', 'save_time': 0.9863252000000102, 'load_time': 1.0871359000000211, 'file_size': 145280253}
# {'file_name': 'lvl2_blosc:snappy_initial.h5', 'save_time': 1.0346236999999974, 'load_time': 1.0896160000000066, 'file_size': 145280253}
# {'file_name': 'lvl3_blosc:snappy_initial.h5', 'save_time': 0.9885836999999924, 'load_time': 1.0724102000000073, 'file_size': 145280253}
# {'file_name': 'lvl4_blosc:snappy_initial.h5', 'save_time': 1.1660128000000043, 'load_time': 1.0799239000000114, 'file_size': 145280253}
# {'file_name': 'lvl5_blosc:snappy_initial.h5', 'save_time': 0.9939644000000101, 'load_time': 1.0625943999999947, 'file_size': 145280253}
# {'file_name': 'lvl6_blosc:snappy_initial.h5', 'save_time': 1.1859230000000025, 'load_time': 1.0543846999999857, 'file_size': 145280253}
# {'file_name': 'lvl7_blosc:snappy_initial.h5', 'save_time': 1.0029427000000055, 'load_time': 1.0639255000000105, 'file_size': 145280253}
# {'file_name': 'lvl8_blosc:snappy_initial.h5', 'save_time': 1.0692114000000004, 'load_time': 1.054091600000021, 'file_size': 145280253}
# {'file_name': 'lvl9_blosc:snappy_initial.h5', 'save_time': 1.1583703999999955, 'load_time': 1.0726514000000122, 'file_size': 145280253}
# {'file_name': 'lvl1_blosc:zlib_initial.h5', 'save_time': 1.37462739999998, 'load_time': 1.1714997999999923, 'file_size': 128733687}
# {'file_name': 'lvl2_blosc:zlib_initial.h5', 'save_time': 1.8939090000000078, 'load_time': 1.1845127999999931, 'file_size': 128733831}
# {'file_name': 'lvl3_blosc:zlib_initial.h5', 'save_time': 1.4617384000000015, 'load_time': 1.1686853999999869, 'file_size': 128733825}
# {'file_name': 'lvl4_blosc:zlib_initial.h5', 'save_time': 2.0446455999999955, 'load_time': 1.2430553000000089, 'file_size': 128430127}
# {'file_name': 'lvl5_blosc:zlib_initial.h5', 'save_time': 1.7347075000000132, 'load_time': 1.2337142999999742, 'file_size': 128436098}
# {'file_name': 'lvl6_blosc:zlib_initial.h5', 'save_time': 1.8166716000000065, 'load_time': 1.228011400000014, 'file_size': 128434324}
# {'file_name': 'lvl7_blosc:zlib_initial.h5', 'save_time': 1.787668300000007, 'load_time': 1.2440437999999858, 'file_size': 128417290}
# {'file_name': 'lvl8_blosc:zlib_initial.h5', 'save_time': 2.050475000000006, 'load_time': 1.2309938000000216, 'file_size': 128385332}
# {'file_name': 'lvl9_blosc:zlib_initial.h5', 'save_time': 1.8449461999999812, 'load_time': 1.3050976000000105, 'file_size': 128385043}
# {'file_name': 'lvl1_blosc:zstd_initial.h5', 'save_time': 1.1853044000000068, 'load_time': 1.0888105000000223, 'file_size': 163178238}
# {'file_name': 'lvl2_blosc:zstd_initial.h5', 'save_time': 1.10679829999998, 'load_time': 1.0499313000000257, 'file_size': 139702599}
# {'file_name': 'lvl3_blosc:zstd_initial.h5', 'save_time': 1.6452489000000128, 'load_time': 1.038135699999998, 'file_size': 127923569}
# {'file_name': 'lvl4_blosc:zstd_initial.h5', 'save_time': 1.9506456999999955, 'load_time': 1.0405537000000322, 'file_size': 127923241}
# {'file_name': 'lvl5_blosc:zstd_initial.h5', 'save_time': 1.8884726999999657, 'load_time': 1.042630499999973, 'file_size': 127923243}
# {'file_name': 'lvl6_blosc:zstd_initial.h5', 'save_time': 1.8678887000000373, 'load_time': 1.0451522000000182, 'file_size': 127923262}
# {'file_name': 'lvl7_blosc:zstd_initial.h5', 'save_time': 2.064217699999972, 'load_time': 1.0386237999999821, 'file_size': 127879370}
# {'file_name': 'lvl8_blosc:zstd_initial.h5', 'save_time': 2.659038399999986, 'load_time': 1.0367658999999776, 'file_size': 127926237}
# {'file_name': 'lvl9_blosc:zstd_initial.h5', 'save_time': 3.9154251999999587, 'load_time': 1.0474128999999834, 'file_size': 127888623}
# {'file_name': 'snappy_initial.parquet', 'save_time': 1.8576105999999868, 'load_time': 1.1722177999999985, 'file_size': 7113701}
# {'file_name': 'gzip_initial.parquet', 'save_time': 2.0321089999999913, 'load_time': 1.1768733000000111, 'file_size': 735276}
# {'file_name': 'brotli_initial.parquet', 'save_time': 2.1875991, 'load_time': 1.17080279999999, 'file_size': 231800}

# %%
optimised_df = df.copy()
optimised_df['value'] = optimised_df['value'].astype('float32')
optimised_df['identifier'] = optimised_df['identifier'].astype('category')
optimised_df['date'] = optimised_df['value'].astype('category')

# %%
optimised_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9003000 entries, 0 to 2999
# Data columns (total 3 columns):
# identifier    category
# value         float32
# date          category
# dtypes: category(2), float32(1)
# memory usage: 137.6 MB

# %%
for comp_engine in h_compression_engines:
    for c_level in range(1, 10):
        result = test_and_benchmark(
            df.to_hdf,
            f'lvl{c_level}_{comp_engine}_optimised.h5',
            pd.read_hdf,
            complib=comp_engine,
            complevel=c_level,
            key='df',
            is_h5=True
        )
        records.append(result)
# Out:
# {'file_name': 'lvl1_zlib_optimised.h5', 'save_time': 1.6550492000000077, 'load_time': 1.170646300000044, 'file_size': 171790243}
# {'file_name': 'lvl2_zlib_optimised.h5', 'save_time': 2.182313899999997, 'load_time': 1.1663815999999656, 'file_size': 171790208}
# {'file_name': 'lvl3_zlib_optimised.h5', 'save_time': 1.539382900000021, 'load_time': 1.1755056999999738, 'file_size': 171790068}
# {'file_name': 'lvl4_zlib_optimised.h5', 'save_time': 1.976733500000023, 'load_time': 1.251539800000046, 'file_size': 171502456}
# {'file_name': 'lvl5_zlib_optimised.h5', 'save_time': 1.9802776000000222, 'load_time': 1.245097200000032, 'file_size': 171515864}
# {'file_name': 'lvl6_zlib_optimised.h5', 'save_time': 2.090701499999966, 'load_time': 1.255020400000035, 'file_size': 171512552}
# {'file_name': 'lvl7_zlib_optimised.h5', 'save_time': 2.1953942000000097, 'load_time': 1.2575075999999967, 'file_size': 171486018}
# {'file_name': 'lvl8_zlib_optimised.h5', 'save_time': 2.3257615999999643, 'load_time': 1.252065200000004, 'file_size': 171414065}
# {'file_name': 'lvl9_zlib_optimised.h5', 'save_time': 2.23128829999996, 'load_time': 1.243105899999989, 'file_size': 171413468}
# {'file_name': 'lvl1_lzo_optimised.h5', 'save_time': 1.2498428000000104, 'load_time': 1.1220473999999854, 'file_size': 183168181}
# {'file_name': 'lvl2_lzo_optimised.h5', 'save_time': 1.2295401000000084, 'load_time': 1.1784046000000217, 'file_size': 183168181}
# {'file_name': 'lvl3_lzo_optimised.h5', 'save_time': 1.1861610999999925, 'load_time': 1.1382017999999903, 'file_size': 183168181}
# {'file_name': 'lvl4_lzo_optimised.h5', 'save_time': 1.1876283000000285, 'load_time': 1.1685371000000373, 'file_size': 183168181}
# {'file_name': 'lvl5_lzo_optimised.h5', 'save_time': 1.2589634000000274, 'load_time': 1.1394719999999552, 'file_size': 183168181}
# {'file_name': 'lvl6_lzo_optimised.h5', 'save_time': 2.1499031000000173, 'load_time': 1.14024059999997, 'file_size': 183168181}
# {'file_name': 'lvl7_lzo_optimised.h5', 'save_time': 1.4167214999999942, 'load_time': 1.1292157999999972, 'file_size': 183168181}
# {'file_name': 'lvl8_lzo_optimised.h5', 'save_time': 1.2316842999999835, 'load_time': 1.1473035999999865, 'file_size': 183168181}
# {'file_name': 'lvl9_lzo_optimised.h5', 'save_time': 1.3740384000000176, 'load_time': 1.1313001999999983, 'file_size': 183168181}
# {'file_name': 'lvl1_bzip2_optimised.h5', 'save_time': 8.552605299999982, 'load_time': 2.767002600000012, 'file_size': 179230320}
# {'file_name': 'lvl2_bzip2_optimised.h5', 'save_time': 7.860407899999984, 'load_time': 2.8121022999999923, 'file_size': 178437129}
# {'file_name': 'lvl3_bzip2_optimised.h5', 'save_time': 8.193159400000013, 'load_time': 2.9536847999999623, 'file_size': 178437129}
# {'file_name': 'lvl4_bzip2_optimised.h5', 'save_time': 8.331585700000005, 'load_time': 2.9818515000000048, 'file_size': 178437129}
# {'file_name': 'lvl5_bzip2_optimised.h5', 'save_time': 8.3201727, 'load_time': 3.084831699999995, 'file_size': 178437129}
# {'file_name': 'lvl6_bzip2_optimised.h5', 'save_time': 8.367995099999973, 'load_time': 2.9851158999999825, 'file_size': 178437129}
# {'file_name': 'lvl7_bzip2_optimised.h5', 'save_time': 8.20505929999996, 'load_time': 2.9932054999999878, 'file_size': 178437129}
# {'file_name': 'lvl8_bzip2_optimised.h5', 'save_time': 8.279343299999994, 'load_time': 3.0185941999999955, 'file_size': 178437129}
# {'file_name': 'lvl9_bzip2_optimised.h5', 'save_time': 8.299143399999991, 'load_time': 3.1859304999999836, 'file_size': 178437129}
# {'file_name': 'lvl1_blosc_optimised.h5', 'save_time': 1.9534667000000354, 'load_time': 1.038256199999978, 'file_size': 222838967}
# {'file_name': 'lvl2_blosc_optimised.h5', 'save_time': 1.0899847000000022, 'load_time': 1.0393321000000242, 'file_size': 171865808}
# {'file_name': 'lvl3_blosc_optimised.h5', 'save_time': 1.298424300000022, 'load_time': 1.039207900000008, 'file_size': 171865808}
# {'file_name': 'lvl4_blosc_optimised.h5', 'save_time': 1.5063220000000115, 'load_time': 1.0260987999999998, 'file_size': 171865808}
# {'file_name': 'lvl5_blosc_optimised.h5', 'save_time': 1.2019667999999797, 'load_time': 1.02585160000001, 'file_size': 171865808}
# {'file_name': 'lvl6_blosc_optimised.h5', 'save_time': 1.154466799999966, 'load_time': 1.022741099999962, 'file_size': 171865808}
# {'file_name': 'lvl7_blosc_optimised.h5', 'save_time': 1.1094714999999837, 'load_time': 1.0333583999999973, 'file_size': 171865808}
# {'file_name': 'lvl8_blosc_optimised.h5', 'save_time': 1.6215037000000052, 'load_time': 1.0213976999999659, 'file_size': 171865808}
# {'file_name': 'lvl9_blosc_optimised.h5', 'save_time': 1.7024053000000094, 'load_time': 1.02512999999999, 'file_size': 171865808}
# {'file_name': 'lvl1_blosc:blosclz_optimised.h5', 'save_time': 1.4186573999999723, 'load_time': 1.031199000000015, 'file_size': 222838991}
# {'file_name': 'lvl2_blosc:blosclz_optimised.h5', 'save_time': 1.1962487000000124, 'load_time': 1.022734000000014, 'file_size': 171865832}
# {'file_name': 'lvl3_blosc:blosclz_optimised.h5', 'save_time': 1.117536599999994, 'load_time': 1.0306728999999564, 'file_size': 171865832}
# {'file_name': 'lvl4_blosc:blosclz_optimised.h5', 'save_time': 1.715601700000036, 'load_time': 1.0471175999999787, 'file_size': 171865832}
# {'file_name': 'lvl5_blosc:blosclz_optimised.h5', 'save_time': 1.2469070000000215, 'load_time': 1.0196647000000212, 'file_size': 171865832}
# {'file_name': 'lvl6_blosc:blosclz_optimised.h5', 'save_time': 1.3287348999999722, 'load_time': 1.0370506000000432, 'file_size': 171865832}
# {'file_name': 'lvl7_blosc:blosclz_optimised.h5', 'save_time': 1.1521685999999818, 'load_time': 1.0273751999999945, 'file_size': 171865832}
# {'file_name': 'lvl8_blosc:blosclz_optimised.h5', 'save_time': 1.4123356000000058, 'load_time': 1.1227198999999928, 'file_size': 171865832}
# {'file_name': 'lvl9_blosc:blosclz_optimised.h5', 'save_time': 1.1792277999999783, 'load_time': 1.053097800000046, 'file_size': 171865832}
# {'file_name': 'lvl1_blosc:lz4_optimised.h5', 'save_time': 1.115370100000007, 'load_time': 1.041478600000005, 'file_size': 171579598}
# {'file_name': 'lvl2_blosc:lz4_optimised.h5', 'save_time': 1.2047435000000064, 'load_time': 1.125175400000046, 'file_size': 171540900}
# {'file_name': 'lvl3_blosc:lz4_optimised.h5', 'save_time': 1.6711756000000264, 'load_time': 1.0630486000000587, 'file_size': 171490923}
# {'file_name': 'lvl4_blosc:lz4_optimised.h5', 'save_time': 1.157015699999988, 'load_time': 1.0461917000000085, 'file_size': 171532613}
# {'file_name': 'lvl5_blosc:lz4_optimised.h5', 'save_time': 1.174381799999992, 'load_time': 1.0660957000000053, 'file_size': 171576222}
# {'file_name': 'lvl6_blosc:lz4_optimised.h5', 'save_time': 1.3399683000000095, 'load_time': 1.0445705000000771, 'file_size': 171562540}
# {'file_name': 'lvl7_blosc:lz4_optimised.h5', 'save_time': 1.1226821999999856, 'load_time': 1.0408386999999948, 'file_size': 171498954}
# {'file_name': 'lvl8_blosc:lz4_optimised.h5', 'save_time': 1.4239067999999406, 'load_time': 1.0513912000000118, 'file_size': 171584273}
# {'file_name': 'lvl9_blosc:lz4_optimised.h5', 'save_time': 1.216292199999998, 'load_time': 1.0430330000000367, 'file_size': 171540965}
# {'file_name': 'lvl1_blosc:lz4hc_optimised.h5', 'save_time': 1.6831892000000153, 'load_time': 1.0356535999999323, 'file_size': 171619463}
# {'file_name': 'lvl2_blosc:lz4hc_optimised.h5', 'save_time': 1.208778900000084, 'load_time': 1.047749500000009, 'file_size': 171619463}
# {'file_name': 'lvl3_blosc:lz4hc_optimised.h5', 'save_time': 1.233939200000009, 'load_time': 1.0408390000000054, 'file_size': 171619175}
# {'file_name': 'lvl4_blosc:lz4hc_optimised.h5', 'save_time': 1.383182099999999, 'load_time': 1.0338415999999597, 'file_size': 171618890}
# {'file_name': 'lvl5_blosc:lz4hc_optimised.h5', 'save_time': 1.29186059999995, 'load_time': 1.0337971999999809, 'file_size': 171618889}
# {'file_name': 'lvl6_blosc:lz4hc_optimised.h5', 'save_time': 1.3462729000000309, 'load_time': 1.048313599999915, 'file_size': 171618858}
# {'file_name': 'lvl7_blosc:lz4hc_optimised.h5', 'save_time': 1.2128680000000713, 'load_time': 1.0472467000000734, 'file_size': 171618795}
# {'file_name': 'lvl8_blosc:lz4hc_optimised.h5', 'save_time': 1.4585890999999265, 'load_time': 1.0512902999998914, 'file_size': 171618653}
# {'file_name': 'lvl9_blosc:lz4hc_optimised.h5', 'save_time': 1.376190500000007, 'load_time': 1.0385109999999713, 'file_size': 171618653}
# {'file_name': 'lvl1_blosc:snappy_optimised.h5', 'save_time': 1.6688656000000037, 'load_time': 1.0653891999999132, 'file_size': 188234398}
# {'file_name': 'lvl2_blosc:snappy_optimised.h5', 'save_time': 2.456196699999964, 'load_time': 1.0869629000000032, 'file_size': 188234398}
# {'file_name': 'lvl3_blosc:snappy_optimised.h5', 'save_time': 1.288898099999983, 'load_time': 1.0639520999999377, 'file_size': 188234398}
# {'file_name': 'lvl4_blosc:snappy_optimised.h5', 'save_time': 1.4712614999999687, 'load_time': 1.0640165000000934, 'file_size': 188234398}
# {'file_name': 'lvl5_blosc:snappy_optimised.h5', 'save_time': 1.4030338000000029, 'load_time': 1.0528432999999495, 'file_size': 188234398}
# {'file_name': 'lvl6_blosc:snappy_optimised.h5', 'save_time': 1.8123690999999553, 'load_time': 1.0678437999999915, 'file_size': 188234398}
# {'file_name': 'lvl7_blosc:snappy_optimised.h5', 'save_time': 1.181080800000018, 'load_time': 1.0652630000000727, 'file_size': 188234398}
# {'file_name': 'lvl8_blosc:snappy_optimised.h5', 'save_time': 1.216287199999897, 'load_time': 1.0571082999999817, 'file_size': 188234398}
# {'file_name': 'lvl9_blosc:snappy_optimised.h5', 'save_time': 1.419647800000007, 'load_time': 1.0627643000000262, 'file_size': 188234398}
# {'file_name': 'lvl1_blosc:zlib_optimised.h5', 'save_time': 1.757078100000058, 'load_time': 1.1815341999999873, 'file_size': 171673671}
# {'file_name': 'lvl2_blosc:zlib_optimised.h5', 'save_time': 1.5869507999999541, 'load_time': 1.1660573999999997, 'file_size': 171673815}
# {'file_name': 'lvl3_blosc:zlib_optimised.h5', 'save_time': 2.146439600000008, 'load_time': 1.1744605999999749, 'file_size': 171673809}
# {'file_name': 'lvl4_blosc:zlib_optimised.h5', 'save_time': 2.069081200000028, 'load_time': 1.2437722999999323, 'file_size': 171375900}
# {'file_name': 'lvl5_blosc:zlib_optimised.h5', 'save_time': 1.9159299000000374, 'load_time': 1.242175399999951, 'file_size': 171381715}
# {'file_name': 'lvl6_blosc:zlib_optimised.h5', 'save_time': 1.9347375999999485, 'load_time': 1.2350706000000855, 'file_size': 171379994}
# {'file_name': 'lvl7_blosc:zlib_optimised.h5', 'save_time': 2.0125757000000704, 'load_time': 1.2422831999999744, 'file_size': 171363424}
# {'file_name': 'lvl8_blosc:zlib_optimised.h5', 'save_time': 2.361754700000006, 'load_time': 1.231517800000006, 'file_size': 171332291}
# {'file_name': 'lvl9_blosc:zlib_optimised.h5', 'save_time': 2.075507499999958, 'load_time': 1.22940339999991, 'file_size': 171332010}
# {'file_name': 'lvl1_blosc:zstd_optimised.h5', 'save_time': 1.4352724999999964, 'load_time': 1.0747873000000254, 'file_size': 206131586}
# {'file_name': 'lvl2_blosc:zstd_optimised.h5', 'save_time': 1.3965606000000435, 'load_time': 1.066484599999967, 'file_size': 182643601}
# {'file_name': 'lvl3_blosc:zstd_optimised.h5', 'save_time': 1.9278808000000254, 'load_time': 1.0635757999999669, 'file_size': 170870550}
# {'file_name': 'lvl4_blosc:zstd_optimised.h5', 'save_time': 1.87641229999997, 'load_time': 1.0394195999999738, 'file_size': 170870232}
# {'file_name': 'lvl5_blosc:zstd_optimised.h5', 'save_time': 2.051023999999984, 'load_time': 1.0552245000000084, 'file_size': 170870234}
# {'file_name': 'lvl6_blosc:zstd_optimised.h5', 'save_time': 2.0587004000000206, 'load_time': 1.0692583000000013, 'file_size': 170870252}
# {'file_name': 'lvl7_blosc:zstd_optimised.h5', 'save_time': 2.2726281999999856, 'load_time': 1.0644578000000138, 'file_size': 170827622}
# {'file_name': 'lvl8_blosc:zstd_optimised.h5', 'save_time': 3.0622384000000693, 'load_time': 1.0746743000000833, 'file_size': 170876839}
# {'file_name': 'lvl9_blosc:zstd_optimised.h5', 'save_time': 4.0572312999998985, 'load_time': 1.094348400000058, 'file_size': 170840387}

# %%
result_df = pd.DataFrame.from_records(records, index='file_name')
result_df.head()
# Out:
#                       file_size  load_time  save_time
# file_name
# lvl1_zlib_initial.h5  128683644   1.180476   1.925198
# lvl2_zlib_initial.h5  128683603   1.220902   1.526238
# lvl3_zlib_initial.h5  128683459   1.227073   1.508373
# lvl4_zlib_initial.h5  128389366   1.300382   1.943003
# lvl5_zlib_initial.h5  128403136   1.264533   1.934719

# %%
df.to_csv('no_compression.csv')

# %%
no_comp_filesize = os.path.getsize('no_compression.csv')

# %%
result_df['compression_ratio'] = no_comp_filesize / result_df['file_size']

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()
TOOLS="hover,crosshair,pan,wheel_zoom,zoom_in,zoom_out,box_zoom,undo,redo,reset,tap,save,box_select,poly_select,lasso_select,"

p = figure(
    tools=TOOLS,
    tooltips=[
        ("File", "@file_name"),
        ("load_time", "$x"),
        ("compression_ratio", "$y"),
    ],
    y_axis_type="log",
    title="Effects of compression on load time",
    y_axis_label='Compression Ratio vs CSV',
    x_axis_label='Time to decompress (s)',
)

p.scatter(
    source=result_df,
    x='load_time',
    y='compression_ratio',
    marker='circle'
)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="994782d1-a4cf-47de-ab29-538b6993f9e3"></div>

# %%
p = figure(
    tools=TOOLS,
    tooltips=[
        ("File", "@file_name"),
        ("Decompression (s)", "$x"),
        ("Compression (s)", "$y"),
    ],
    title="Association between compression and decompression time",
    y_axis_label='Time to compress (s)',
    x_axis_label='Time to decompress (s)',
)

p.scatter(
    source=result_df,
    x='load_time',
    y='save_time',
    marker='circle'
)
show(p)
# Out:
#   <div class="bk-root" id="06604ea5-24da-44b5-93fb-5629f83b8c8f"></div>

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(result_df)
# Out:
#                                  file_size  load_time  save_time  \
# file_name
# lvl1_zlib_initial.h5             128683644   1.180476   1.925198
# lvl2_zlib_initial.h5             128683603   1.220902   1.526238
# lvl3_zlib_initial.h5             128683459   1.227073   1.508373
# lvl4_zlib_initial.h5             128389366   1.300382   1.943003
# lvl5_zlib_initial.h5             128403136   1.264533   1.934719
# lvl6_zlib_initial.h5             128399712   1.246162   1.988434
# lvl7_zlib_initial.h5             128372460   1.256615   1.975600
# lvl8_zlib_initial.h5             128320512   1.244064   2.011139
# lvl9_zlib_initial.h5             128319923   1.235851   1.925217
# lvl1_lzo_initial.h5              140190352   1.117739   1.011438
# lvl2_lzo_initial.h5              140190352   1.120660   0.934485
# lvl3_lzo_initial.h5              140190352   1.123009   0.968235
# lvl4_lzo_initial.h5              140190352   1.113953   0.932181
# lvl5_lzo_initial.h5              140190352   1.119055   0.945864
# lvl6_lzo_initial.h5              140190352   1.123652   0.952621
# lvl7_lzo_initial.h5              140190352   1.116576   1.000146
# lvl8_lzo_initial.h5              140190352   1.147833   0.935944
# lvl9_lzo_initial.h5              140190352   1.222265   0.958335
# lvl1_bzip2_initial.h5            136284145   2.777060   8.386686
# lvl2_bzip2_initial.h5            135475488   2.772354   7.799761
# lvl3_bzip2_initial.h5            135475488   3.010550   8.178041
# lvl4_bzip2_initial.h5            135475488   2.984151   8.421554
# lvl5_bzip2_initial.h5            135475488   3.094494   8.181653
# lvl6_bzip2_initial.h5            135475488   3.008880   8.316864
# lvl7_bzip2_initial.h5            135475488   3.068353   8.292681
# lvl8_bzip2_initial.h5            135475488   3.187060   8.221417
# lvl9_bzip2_initial.h5            135475488   2.997299   8.510163
# lvl1_blosc_initial.h5            179808664   1.047087   0.986405
# lvl2_blosc_initial.h5            128861576   1.055542   0.968597
# lvl3_blosc_initial.h5            128861576   1.069402   1.046168
# lvl4_blosc_initial.h5            128861576   1.028193   0.962704
# lvl5_blosc_initial.h5            128861576   1.040207   0.996007
# lvl6_blosc_initial.h5            128861576   1.029472   0.991097
# lvl7_blosc_initial.h5            128861576   1.046481   1.052284
# lvl8_blosc_initial.h5            128861576   1.087409   1.393154
# lvl9_blosc_initial.h5            128861576   1.051246   0.982711
# lvl1_blosc:blosclz_initial.h5    179808704   1.056972   1.055144
# lvl2_blosc:blosclz_initial.h5    128861616   1.066558   0.986537
# lvl3_blosc:blosclz_initial.h5    128861616   1.020349   1.001961
# lvl4_blosc:blosclz_initial.h5    128861616   1.027817   0.997009
# lvl5_blosc:blosclz_initial.h5    128861616   1.027023   1.058350
# lvl6_blosc:blosclz_initial.h5    128861616   1.023464   1.018816
# lvl7_blosc:blosclz_initial.h5    128861616   1.073479   1.020172
# lvl8_blosc:blosclz_initial.h5    128861616   1.140532   0.982717
# lvl9_blosc:blosclz_initial.h5    128861616   1.133608   1.197489
# lvl1_blosc:lz4_initial.h5        128578198   1.101149   0.976800
# lvl2_blosc:lz4_initial.h5        128538260   1.148447   0.947280
# lvl3_blosc:lz4_initial.h5        128553551   1.033715   0.949128
# lvl4_blosc:lz4_initial.h5        128552074   1.047806   0.949988
# lvl5_blosc:lz4_initial.h5        128597063   1.047916   0.924353
# lvl6_blosc:lz4_initial.h5        128538238   1.044749   0.959974
# lvl7_blosc:lz4_initial.h5        128539246   1.077623   0.953639
# lvl8_blosc:lz4_initial.h5        128538314   1.060464   0.973222
# lvl9_blosc:lz4_initial.h5        128538294   1.049380   1.488486
# lvl1_blosc:lz4hc_initial.h5      128507974   1.070002   1.031105
# lvl2_blosc:lz4hc_initial.h5      128507974   1.091896   1.060663
# lvl3_blosc:lz4hc_initial.h5      128507675   1.080514   1.037565
# lvl4_blosc:lz4hc_initial.h5      128507383   1.092396   1.064576
# lvl5_blosc:lz4hc_initial.h5      128507382   1.068625   1.083083
# lvl6_blosc:lz4hc_initial.h5      128507349   1.054642   1.073645
# lvl7_blosc:lz4hc_initial.h5      128507284   1.055579   1.120488
# lvl8_blosc:lz4hc_initial.h5      128507134   1.101805   1.578451
# lvl9_blosc:lz4hc_initial.h5      128507134   1.048642   1.692725
# lvl1_blosc:snappy_initial.h5     145280253   1.087136   0.986325
# lvl2_blosc:snappy_initial.h5     145280253   1.089616   1.034624
# lvl3_blosc:snappy_initial.h5     145280253   1.072410   0.988584
# lvl4_blosc:snappy_initial.h5     145280253   1.079924   1.166013
# lvl5_blosc:snappy_initial.h5     145280253   1.062594   0.993964
# lvl6_blosc:snappy_initial.h5     145280253   1.054385   1.185923
# lvl7_blosc:snappy_initial.h5     145280253   1.063926   1.002943
# lvl8_blosc:snappy_initial.h5     145280253   1.054092   1.069211
# lvl9_blosc:snappy_initial.h5     145280253   1.072651   1.158370
# lvl1_blosc:zlib_initial.h5       128733687   1.171500   1.374627
# lvl2_blosc:zlib_initial.h5       128733831   1.184513   1.893909
# lvl3_blosc:zlib_initial.h5       128733825   1.168685   1.461738
# lvl4_blosc:zlib_initial.h5       128430127   1.243055   2.044646
# lvl5_blosc:zlib_initial.h5       128436098   1.233714   1.734708
# lvl6_blosc:zlib_initial.h5       128434324   1.228011   1.816672
# lvl7_blosc:zlib_initial.h5       128417290   1.244044   1.787668
# lvl8_blosc:zlib_initial.h5       128385332   1.230994   2.050475
# lvl9_blosc:zlib_initial.h5       128385043   1.305098   1.844946
# lvl1_blosc:zstd_initial.h5       163178238   1.088811   1.185304
# lvl2_blosc:zstd_initial.h5       139702599   1.049931   1.106798
# lvl3_blosc:zstd_initial.h5       127923569   1.038136   1.645249
# lvl4_blosc:zstd_initial.h5       127923241   1.040554   1.950646
# lvl5_blosc:zstd_initial.h5       127923243   1.042630   1.888473
# lvl6_blosc:zstd_initial.h5       127923262   1.045152   1.867889
# lvl7_blosc:zstd_initial.h5       127879370   1.038624   2.064218
# lvl8_blosc:zstd_initial.h5       127926237   1.036766   2.659038
# lvl9_blosc:zstd_initial.h5       127888623   1.047413   3.915425
# snappy_initial.parquet             7113701   1.172218   1.857611
# gzip_initial.parquet                735276   1.176873   2.032109
# brotli_initial.parquet              231800   1.170803   2.187599
# lvl1_zlib_optimised.h5           171790243   1.170646   1.655049
# lvl2_zlib_optimised.h5           171790208   1.166382   2.182314
# lvl3_zlib_optimised.h5           171790068   1.175506   1.539383
# lvl4_zlib_optimised.h5           171502456   1.251540   1.976734
# lvl5_zlib_optimised.h5           171515864   1.245097   1.980278
# lvl6_zlib_optimised.h5           171512552   1.255020   2.090701
# lvl7_zlib_optimised.h5           171486018   1.257508   2.195394
# lvl8_zlib_optimised.h5           171414065   1.252065   2.325762
# lvl9_zlib_optimised.h5           171413468   1.243106   2.231288
# lvl1_lzo_optimised.h5            183168181   1.122047   1.249843
# lvl2_lzo_optimised.h5            183168181   1.178405   1.229540
# lvl3_lzo_optimised.h5            183168181   1.138202   1.186161
# lvl4_lzo_optimised.h5            183168181   1.168537   1.187628
# lvl5_lzo_optimised.h5            183168181   1.139472   1.258963
# lvl6_lzo_optimised.h5            183168181   1.140241   2.149903
# lvl7_lzo_optimised.h5            183168181   1.129216   1.416721
# lvl8_lzo_optimised.h5            183168181   1.147304   1.231684
# lvl9_lzo_optimised.h5            183168181   1.131300   1.374038
# lvl1_bzip2_optimised.h5          179230320   2.767003   8.552605
# lvl2_bzip2_optimised.h5          178437129   2.812102   7.860408
# lvl3_bzip2_optimised.h5          178437129   2.953685   8.193159
# lvl4_bzip2_optimised.h5          178437129   2.981852   8.331586
# lvl5_bzip2_optimised.h5          178437129   3.084832   8.320173
# lvl6_bzip2_optimised.h5          178437129   2.985116   8.367995
# lvl7_bzip2_optimised.h5          178437129   2.993205   8.205059
# lvl8_bzip2_optimised.h5          178437129   3.018594   8.279343
# lvl9_bzip2_optimised.h5          178437129   3.185930   8.299143
# lvl1_blosc_optimised.h5          222838967   1.038256   1.953467
# lvl2_blosc_optimised.h5          171865808   1.039332   1.089985
# lvl3_blosc_optimised.h5          171865808   1.039208   1.298424
# lvl4_blosc_optimised.h5          171865808   1.026099   1.506322
# lvl5_blosc_optimised.h5          171865808   1.025852   1.201967
# lvl6_blosc_optimised.h5          171865808   1.022741   1.154467
# lvl7_blosc_optimised.h5          171865808   1.033358   1.109471
# lvl8_blosc_optimised.h5          171865808   1.021398   1.621504
# lvl9_blosc_optimised.h5          171865808   1.025130   1.702405
# lvl1_blosc:blosclz_optimised.h5  222838991   1.031199   1.418657
# lvl2_blosc:blosclz_optimised.h5  171865832   1.022734   1.196249
# lvl3_blosc:blosclz_optimised.h5  171865832   1.030673   1.117537
# lvl4_blosc:blosclz_optimised.h5  171865832   1.047118   1.715602
# lvl5_blosc:blosclz_optimised.h5  171865832   1.019665   1.246907
# lvl6_blosc:blosclz_optimised.h5  171865832   1.037051   1.328735
# lvl7_blosc:blosclz_optimised.h5  171865832   1.027375   1.152169
# lvl8_blosc:blosclz_optimised.h5  171865832   1.122720   1.412336
# lvl9_blosc:blosclz_optimised.h5  171865832   1.053098   1.179228
# lvl1_blosc:lz4_optimised.h5      171579598   1.041479   1.115370
# lvl2_blosc:lz4_optimised.h5      171540900   1.125175   1.204744
# lvl3_blosc:lz4_optimised.h5      171490923   1.063049   1.671176
# lvl4_blosc:lz4_optimised.h5      171532613   1.046192   1.157016
# lvl5_blosc:lz4_optimised.h5      171576222   1.066096   1.174382
# lvl6_blosc:lz4_optimised.h5      171562540   1.044571   1.339968
# lvl7_blosc:lz4_optimised.h5      171498954   1.040839   1.122682
# lvl8_blosc:lz4_optimised.h5      171584273   1.051391   1.423907
# lvl9_blosc:lz4_optimised.h5      171540965   1.043033   1.216292
# lvl1_blosc:lz4hc_optimised.h5    171619463   1.035654   1.683189
# lvl2_blosc:lz4hc_optimised.h5    171619463   1.047750   1.208779
# lvl3_blosc:lz4hc_optimised.h5    171619175   1.040839   1.233939
# lvl4_blosc:lz4hc_optimised.h5    171618890   1.033842   1.383182
# lvl5_blosc:lz4hc_optimised.h5    171618889   1.033797   1.291861
# lvl6_blosc:lz4hc_optimised.h5    171618858   1.048314   1.346273
# lvl7_blosc:lz4hc_optimised.h5    171618795   1.047247   1.212868
# lvl8_blosc:lz4hc_optimised.h5    171618653   1.051290   1.458589
# lvl9_blosc:lz4hc_optimised.h5    171618653   1.038511   1.376191
# lvl1_blosc:snappy_optimised.h5   188234398   1.065389   1.668866
# lvl2_blosc:snappy_optimised.h5   188234398   1.086963   2.456197
# lvl3_blosc:snappy_optimised.h5   188234398   1.063952   1.288898
# lvl4_blosc:snappy_optimised.h5   188234398   1.064017   1.471261
# lvl5_blosc:snappy_optimised.h5   188234398   1.052843   1.403034
# lvl6_blosc:snappy_optimised.h5   188234398   1.067844   1.812369
# lvl7_blosc:snappy_optimised.h5   188234398   1.065263   1.181081
# lvl8_blosc:snappy_optimised.h5   188234398   1.057108   1.216287
# lvl9_blosc:snappy_optimised.h5   188234398   1.062764   1.419648
# lvl1_blosc:zlib_optimised.h5     171673671   1.181534   1.757078
# lvl2_blosc:zlib_optimised.h5     171673815   1.166057   1.586951
# lvl3_blosc:zlib_optimised.h5     171673809   1.174461   2.146440
# lvl4_blosc:zlib_optimised.h5     171375900   1.243772   2.069081
# lvl5_blosc:zlib_optimised.h5     171381715   1.242175   1.915930
# lvl6_blosc:zlib_optimised.h5     171379994   1.235071   1.934738
# lvl7_blosc:zlib_optimised.h5     171363424   1.242283   2.012576
# lvl8_blosc:zlib_optimised.h5     171332291   1.231518   2.361755
# lvl9_blosc:zlib_optimised.h5     171332010   1.229403   2.075507
# lvl1_blosc:zstd_optimised.h5     206131586   1.074787   1.435272
# lvl2_blosc:zstd_optimised.h5     182643601   1.066485   1.396561
# lvl3_blosc:zstd_optimised.h5     170870550   1.063576   1.927881
# lvl4_blosc:zstd_optimised.h5     170870232   1.039420   1.876412
# lvl5_blosc:zstd_optimised.h5     170870234   1.055225   2.051024
# lvl6_blosc:zstd_optimised.h5     170870252   1.069258   2.058700
# lvl7_blosc:zstd_optimised.h5     170827622   1.064458   2.272628
# lvl8_blosc:zstd_optimised.h5     170876839   1.074674   3.062238
# lvl9_blosc:zstd_optimised.h5     170840387   1.094348   4.057231
#
#                                  compression_ratio
# file_name
# lvl1_zlib_initial.h5                      3.210849
# lvl2_zlib_initial.h5                      3.210850
# lvl3_zlib_initial.h5                      3.210853
# lvl4_zlib_initial.h5                      3.218208
# lvl5_zlib_initial.h5                      3.217863
# lvl6_zlib_initial.h5                      3.217949
# lvl7_zlib_initial.h5                      3.218632
# lvl8_zlib_initial.h5                      3.219935
# lvl9_zlib_initial.h5                      3.219950
# lvl1_lzo_initial.h5                       2.947305
# lvl2_lzo_initial.h5                       2.947305
# lvl3_lzo_initial.h5                       2.947305
# lvl4_lzo_initial.h5                       2.947305
# lvl5_lzo_initial.h5                       2.947305
# lvl6_lzo_initial.h5                       2.947305
# lvl7_lzo_initial.h5                       2.947305
# lvl8_lzo_initial.h5                       2.947305
# lvl9_lzo_initial.h5                       2.947305
# lvl1_bzip2_initial.h5                     3.031781
# lvl2_bzip2_initial.h5                     3.049878
# lvl3_bzip2_initial.h5                     3.049878
# lvl4_bzip2_initial.h5                     3.049878
# lvl5_bzip2_initial.h5                     3.049878
# lvl6_bzip2_initial.h5                     3.049878
# lvl7_bzip2_initial.h5                     3.049878
# lvl8_bzip2_initial.h5                     3.049878
# lvl9_bzip2_initial.h5                     3.049878
# lvl1_blosc_initial.h5                     2.297908
# lvl2_blosc_initial.h5                     3.206415
# lvl3_blosc_initial.h5                     3.206415
# lvl4_blosc_initial.h5                     3.206415
# lvl5_blosc_initial.h5                     3.206415
# lvl6_blosc_initial.h5                     3.206415
# lvl7_blosc_initial.h5                     3.206415
# lvl8_blosc_initial.h5                     3.206415
# lvl9_blosc_initial.h5                     3.206415
# lvl1_blosc:blosclz_initial.h5             2.297907
# lvl2_blosc:blosclz_initial.h5             3.206414
# lvl3_blosc:blosclz_initial.h5             3.206414
# lvl4_blosc:blosclz_initial.h5             3.206414
# lvl5_blosc:blosclz_initial.h5             3.206414
# lvl6_blosc:blosclz_initial.h5             3.206414
# lvl7_blosc:blosclz_initial.h5             3.206414
# lvl8_blosc:blosclz_initial.h5             3.206414
# lvl9_blosc:blosclz_initial.h5             3.206414
# lvl1_blosc:lz4_initial.h5                 3.213482
# lvl2_blosc:lz4_initial.h5                 3.214480
# lvl3_blosc:lz4_initial.h5                 3.214098
# lvl4_blosc:lz4_initial.h5                 3.214135
# lvl5_blosc:lz4_initial.h5                 3.213010
# lvl6_blosc:lz4_initial.h5                 3.214481
# lvl7_blosc:lz4_initial.h5                 3.214456
# lvl8_blosc:lz4_initial.h5                 3.214479
# lvl9_blosc:lz4_initial.h5                 3.214479
# lvl1_blosc:lz4hc_initial.h5               3.215238
# lvl2_blosc:lz4hc_initial.h5               3.215238
# lvl3_blosc:lz4hc_initial.h5               3.215245
# lvl4_blosc:lz4hc_initial.h5               3.215253
# lvl5_blosc:lz4hc_initial.h5               3.215253
# lvl6_blosc:lz4hc_initial.h5               3.215254
# lvl7_blosc:lz4hc_initial.h5               3.215255
# lvl8_blosc:lz4hc_initial.h5               3.215259
# lvl9_blosc:lz4hc_initial.h5               3.215259
# lvl1_blosc:snappy_initial.h5              2.844046
# lvl2_blosc:snappy_initial.h5              2.844046
# lvl3_blosc:snappy_initial.h5              2.844046
# lvl4_blosc:snappy_initial.h5              2.844046
# lvl5_blosc:snappy_initial.h5              2.844046
# lvl6_blosc:snappy_initial.h5              2.844046
# lvl7_blosc:snappy_initial.h5              2.844046
# lvl8_blosc:snappy_initial.h5              2.844046
# lvl9_blosc:snappy_initial.h5              2.844046
# lvl1_blosc:zlib_initial.h5                3.209600
# lvl2_blosc:zlib_initial.h5                3.209597
# lvl3_blosc:zlib_initial.h5                3.209597
# lvl4_blosc:zlib_initial.h5                3.217187
# lvl5_blosc:zlib_initial.h5                3.217037
# lvl6_blosc:zlib_initial.h5                3.217082
# lvl7_blosc:zlib_initial.h5                3.217508
# lvl8_blosc:zlib_initial.h5                3.218309
# lvl9_blosc:zlib_initial.h5                3.218317
# lvl1_blosc:zstd_initial.h5                2.532101
# lvl2_blosc:zstd_initial.h5                2.957595
# lvl3_blosc:zstd_initial.h5                3.229926
# lvl4_blosc:zstd_initial.h5                3.229935
# lvl5_blosc:zstd_initial.h5                3.229935
# lvl6_blosc:zstd_initial.h5                3.229934
# lvl7_blosc:zstd_initial.h5                3.231043
# lvl8_blosc:zstd_initial.h5                3.229859
# lvl9_blosc:zstd_initial.h5                3.230809
# snappy_initial.parquet                   58.082805
# gzip_initial.parquet                    561.943686
# brotli_initial.parquet                 1782.500889
# lvl1_zlib_optimised.h5                    2.405164
# lvl2_zlib_optimised.h5                    2.405164
# lvl3_zlib_optimised.h5                    2.405166
# lvl4_zlib_optimised.h5                    2.409200
# lvl5_zlib_optimised.h5                    2.409012
# lvl6_zlib_optimised.h5                    2.409058
# lvl7_zlib_optimised.h5                    2.409431
# lvl8_zlib_optimised.h5                    2.410442
# lvl9_zlib_optimised.h5                    2.410451
# lvl1_lzo_optimised.h5                     2.255761
# lvl2_lzo_optimised.h5                     2.255761
# lvl3_lzo_optimised.h5                     2.255761
# lvl4_lzo_optimised.h5                     2.255761
# lvl5_lzo_optimised.h5                     2.255761
# lvl6_lzo_optimised.h5                     2.255761
# lvl7_lzo_optimised.h5                     2.255761
# lvl8_lzo_optimised.h5                     2.255761
# lvl9_lzo_optimised.h5                     2.255761
# lvl1_bzip2_optimised.h5                   2.305323
# lvl2_bzip2_optimised.h5                   2.315570
# lvl3_bzip2_optimised.h5                   2.315570
# lvl4_bzip2_optimised.h5                   2.315570
# lvl5_bzip2_optimised.h5                   2.315570
# lvl6_bzip2_optimised.h5                   2.315570
# lvl7_bzip2_optimised.h5                   2.315570
# lvl8_bzip2_optimised.h5                   2.315570
# lvl9_bzip2_optimised.h5                   2.315570
# lvl1_blosc_optimised.h5                   1.854181
# lvl2_blosc_optimised.h5                   2.404106
# lvl3_blosc_optimised.h5                   2.404106
# lvl4_blosc_optimised.h5                   2.404106
# lvl5_blosc_optimised.h5                   2.404106
# lvl6_blosc_optimised.h5                   2.404106
# lvl7_blosc_optimised.h5                   2.404106
# lvl8_blosc_optimised.h5                   2.404106
# lvl9_blosc_optimised.h5                   2.404106
# lvl1_blosc:blosclz_optimised.h5           1.854180
# lvl2_blosc:blosclz_optimised.h5           2.404106
# lvl3_blosc:blosclz_optimised.h5           2.404106
# lvl4_blosc:blosclz_optimised.h5           2.404106
# lvl5_blosc:blosclz_optimised.h5           2.404106
# lvl6_blosc:blosclz_optimised.h5           2.404106
# lvl7_blosc:blosclz_optimised.h5           2.404106
# lvl8_blosc:blosclz_optimised.h5           2.404106
# lvl9_blosc:blosclz_optimised.h5           2.404106
# lvl1_blosc:lz4_optimised.h5               2.408117
# lvl2_blosc:lz4_optimised.h5               2.408660
# lvl3_blosc:lz4_optimised.h5               2.409362
# lvl4_blosc:lz4_optimised.h5               2.408776
# lvl5_blosc:lz4_optimised.h5               2.408164
# lvl6_blosc:lz4_optimised.h5               2.408356
# lvl7_blosc:lz4_optimised.h5               2.409249
# lvl8_blosc:lz4_optimised.h5               2.408051
# lvl9_blosc:lz4_optimised.h5               2.408659
# lvl1_blosc:lz4hc_optimised.h5             2.407557
# lvl2_blosc:lz4hc_optimised.h5             2.407557
# lvl3_blosc:lz4hc_optimised.h5             2.407561
# lvl4_blosc:lz4hc_optimised.h5             2.407565
# lvl5_blosc:lz4hc_optimised.h5             2.407565
# lvl6_blosc:lz4hc_optimised.h5             2.407566
# lvl7_blosc:lz4hc_optimised.h5             2.407567
# lvl8_blosc:lz4hc_optimised.h5             2.407569
# lvl9_blosc:lz4hc_optimised.h5             2.407569
# lvl1_blosc:snappy_optimised.h5            2.195049
# lvl2_blosc:snappy_optimised.h5            2.195049
# lvl3_blosc:snappy_optimised.h5            2.195049
# lvl4_blosc:snappy_optimised.h5            2.195049
# lvl5_blosc:snappy_optimised.h5            2.195049
# lvl6_blosc:snappy_optimised.h5            2.195049
# lvl7_blosc:snappy_optimised.h5            2.195049
# lvl8_blosc:snappy_optimised.h5            2.195049
# lvl9_blosc:snappy_optimised.h5            2.195049
# lvl1_blosc:zlib_optimised.h5              2.406797
# lvl2_blosc:zlib_optimised.h5              2.406795
# lvl3_blosc:zlib_optimised.h5              2.406795
# lvl4_blosc:zlib_optimised.h5              2.410979
# lvl5_blosc:zlib_optimised.h5              2.410897
# lvl6_blosc:zlib_optimised.h5              2.410921
# lvl7_blosc:zlib_optimised.h5              2.411155
# lvl8_blosc:zlib_optimised.h5              2.411593
# lvl9_blosc:zlib_optimised.h5              2.411597
# lvl1_blosc:zstd_optimised.h5              2.004466
# lvl2_blosc:zstd_optimised.h5              2.262240
# lvl3_blosc:zstd_optimised.h5              2.418110
# lvl4_blosc:zstd_optimised.h5              2.418114
# lvl5_blosc:zstd_optimised.h5              2.418114
# lvl6_blosc:zstd_optimised.h5              2.418114
# lvl7_blosc:zstd_optimised.h5              2.418717
# lvl8_blosc:zstd_optimised.h5              2.418021
# lvl9_blosc:zstd_optimised.h5              2.418536

# %%
parq = pd.read_parquet('brotli_initial.parquet')
pd.testing.assert_frame_equal(parq, df)
